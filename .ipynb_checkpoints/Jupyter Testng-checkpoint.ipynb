# %%
from utils import *
import pandas as pd

casesdf = loadAndCleanData('COVID-19-master/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
casesdf.head()
# Out:
#                   Province/State Country/Region      Lat      Long  1/22/20  \
# 8   Australian Capital Territory      Australia -35.4735  149.0124        0
# 9                New South Wales      Australia -33.8688  151.2093        0
# 10            Northern Territory      Australia -12.4634  130.8456        0
# 11                    Queensland      Australia -28.0167  153.4000        0
# 12               South Australia      Australia -34.9285  138.6007        0
#
#     1/23/20  1/24/20  1/25/20  1/26/20  1/27/20   ...     4/3/20  4/4/20  \
# 8         0        0        0        0        0   ...         91      93
# 9         0        0        0        3        4   ...       2389    2493
# 10        0        0        0        0        0   ...         22      26
# 11        0        0        0        0        0   ...        873     900
# 12        0        0        0        0        0   ...        396     407
#
#     4/5/20  4/6/20  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  4/12/20
# ...

# %%
def correctDateFormat(dataframe, colname):
    wow = pd.melt(dataframe, id_vars=['Province/State', 'Country/Region'], value_vars=list(casesdf.columns[4:]),
                 var_name='Date', value_name='Confirmed')
    return wow

# %%
newdf = correctDateFormat(casesdf, 'poop')
newdf.tail(50)
# Out:
#                         Province/State  Country/Region variable  Confirmed
# 6674                             Hubei           China  4/12/20      67803
# 6675                             Hunan           China  4/12/20       1019
# 6676                    Inner Mongolia           China  4/12/20        189
# 6677                           Jiangsu           China  4/12/20        653
# 6678                           Jiangxi           China  4/12/20        937
# 6679                             Jilin           China  4/12/20         99
# 6680                          Liaoning           China  4/12/20        145
# 6681                             Macau           China  4/12/20         45
# 6682                           Ningxia           China  4/12/20         75
# 6683                           Qinghai           China  4/12/20         18
# 6684                           Shaanxi           China  4/12/20        256
# ...

# %%
test = "This is a test sentence"
print(test[4:])
# Out:
#  is a test sentence

# %%
list(casesdf.columns[4:])
# Out:
# ['1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/2/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
#  '2/14/20',
#  '2/15/20',
#  '2/16/20',
#  '2/17/20',
#  '2/18/20',
#  '2/19/20',
#  '2/20/20',
#  '2/21/20',
#  '2/22/20',
#  '2/23/20',
#  '2/24/20',
#  '2/25/20',
#  '2/26/20',
#  '2/27/20',
#  '2/28/20',
#  '2/29/20',
#  '3/1/20',
#  '3/2/20',
#  '3/3/20',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/20/20',
#  '3/21/20',
#  '3/22/20',
#  '3/23/20',
#  '3/24/20',
#  '3/25/20',
#  '3/26/20',
#  '3/27/20',
#  '3/28/20',
#  '3/29/20',
#  '3/30/20',
#  '3/31/20',
#  '4/1/20',
#  '4/2/20',
# ...
